# %%
print ("Hello world")
hem = str("Hemm")
def memes():
    print ("Funny")
for i in range(1, 2):
    print ("lol " + str(hem))
# Out:
# Hello world
# lol Hemm

# %%
print ("I am just testing out Jupyters notebook")
# Comment
"""
BIG COMMENT
"""
'''
WEIRD BIG COMMENT
'''
x = float(2.0)
y = float(16.0)
print (x ** y)
# Out:
# I am just testing out Jupyters notebook
# 65536.0
